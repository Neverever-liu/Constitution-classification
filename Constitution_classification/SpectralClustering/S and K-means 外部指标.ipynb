# %%
from sklearn import metrics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('E:/databag/男生data/SpectralClustering聚类(2到7)结果.csv',index_col=0)
data_A = pd.read_csv('E:/databag/男生data/KMeans聚类(2到7)结果.csv',index_col=0)
data1 = data['3个簇']
data2 = data_A['3个簇']

# %%
#NMI
from sklearn.metrics.cluster import normalized_mutual_info_score
print(normalized_mutual_info_score(data1, data2))
# Out:
# 0.6199148751943998

# %%
#AMI
from sklearn import metrics
print(metrics.adjusted_mutual_info_score(data1, data2))
# Out:
# 0.6195480969274778

# %%
#V-measure
print(metrics.homogeneity_score(data1,data2))
print(metrics.completeness_score(data1,data2))
print(metrics.v_measure_score(data1,data2))
# Out:
# 0.6174397837124596
# 0.6224098900245301
# 0.6199148751943997

# %%
data
# Out:
#        性别       肺活量    身高(cm)    体重(kg)  谷丙转氨酶(ALT)(U/L)  总胆红素(TBIL)(umol/L)  \
# 0     0.0  0.534884  0.830416  0.292517         0.066638            0.067114
# 1     0.0  0.395349  0.874179  0.272109         0.071632            0.010640
# 2     0.0  0.534884  0.830416  0.346939         0.020691            0.009003
# 3     0.0  0.348837  0.868709  0.319728         0.049658            0.015960
# 4     0.0  0.511628  0.874179  0.333333         0.058219            0.060566
# ...   ...       ...       ...       ...              ...                 ...
# 4046  1.0  0.372093  0.874179  0.394558         0.018265            0.034416
# 4047  0.0  0.209302  0.824945  0.401361         0.012557            0.013259
# 4048  0.0  0.441860  0.830416  0.387755         0.041096            0.013464
# 4049  0.0  0.186047  0.808534  0.272109         0.023973            0.035808
# 4050  0.0  0.348837  0.824945  0.306122         0.043950            0.041946
#
#       平均血小板体积(MPV)(fl)  白细胞计数(WBC)(10^9/L)  中性粒细胞绝对值(NE#)(10^9/L)  \
# 0                 0.04            0.159420               0.147541
# 1                 0.62            0.217391               0.163934
# 2                 0.50            0.159420               0.122951
# 3                 0.78            0.123188               0.090164
# 4                 0.38            0.224638               0.245902
# ...                ...                 ...                    ...
# 4046              0.50            0.434783               0.516393
# 4047              0.30            0.021739               0.065574
# 4048              0.18            0.528986               0.450820
# 4049              0.28            0.239130               0.237705
# 4050              0.24            0.514493               0.581967
#
#       中性粒细胞比值(NE%)(%)  ...  中间细胞绝对值(MID#)(10^9/L)  红细胞分布宽度(RDW-SD)(%)  \
# 0            0.471495  ...               0.105263            0.250000
# 1            0.395252  ...               0.263158            0.457143
# 2            0.379657  ...               0.210526            0.660714
# 3            0.346734  ...               0.157895            0.425000
# 4            0.677526  ...               0.263158            0.700000
# ...               ...  ...                    ...                 ...
# 4046         0.915093  ...               0.157895            0.564286
# 4047         0.509617  ...               0.052632            0.482143
# 4048         0.603188  ...               0.526316            0.764286
# 4049         0.590885  ...               0.210526            0.810714
# 4050         0.894126  ...               0.263158            0.417857
#
#       血压-高(mmHg)  血压-低(mmHg)  2个簇  3个簇  4个簇  5个簇  6个簇  7个簇
# 0       0.623457    0.316667    1    0    0    0    4    6
# 1       0.623457    0.450000    1    0    0    0    4    6
# 2       0.709877    0.433333    1    0    0    0    4    6
# 3       0.580247    0.433333    1    0    3    2    5    1
# 4       0.641975    0.250000    1    0    3    2    5    1
# ...          ...         ...  ...  ...  ...  ...  ...  ...
# 4046    0.734568    0.666667    0    2    1    4    3    5
# 4047    0.549383    0.750000    1    0    0    0    4    6
# 4048    0.623457    0.566667    1    2    1    0    2    2
# 4049    0.438272    0.250000    1    0    0    0    4    2
# 4050    0.629630    0.633333    1    2    1    4    2    3
#
# [4051 rows x 33 columns]
